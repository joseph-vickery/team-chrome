# %%
import pandas as pd
import numpy as np
import scipy.io
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('T1D_association.csv', sep=',')
display(df)
# Out:
#     Variant and risk allele    P-value P-value annotation    RAF         OR  \
# 0        rs2304256-<b>C</b>   4 x 10-9                NaN   0.71       1.16
# 1         rs941576-<b>A</b>  1 x 10-10                NaN   0.57       1.11
# 2       rs61839660-<b>?</b>   5 x 10-9                NaN     NR        1.6
# 3        rs1265564-<b>?</b>  1 x 10-16                NaN     NR       1.45
# 4       rs55846421-<b>?</b>   2 x 10-9                NaN     NR      0.113
# ..                      ...        ...                ...    ...        ...
# 810     rs12615970-<b>A</b>   9 x 10-9                NaN  0.867  1.3157895
# 811    rs185299109-<b>T</b>   1 x 10-8                NaN  0.007      20.75
# 812    rs149641852-<b>T</b>   1 x 10-8                NaN  0.012       9.01
# 813     rs55703767-<b>G</b>   5 x 10-9                NaN  0.794  1.2987013
# 814     rs55703767-<b>G</b>  4 x 10-10                NaN  0.794  1.2048193
#
#     Beta             CI        Mapped gene  \
# 0     '-    [1.11-1.22]               TYK2
# 1     '-    [1.06-1.16]               MEG3
# 2     '-    [1.44-1.76]              IL2RA
# 3     '-    [1.28-1.67]               CUX2
# 4     '-  [0.081-0.156]               NEMF
# ..   ...            ...                ...
# 810   '-           [NR]               ALLC
# 811   '-           [NR]  LINC00470, AIDAP3
# 812   '-           [NR]   SNCAIP, MGC32805
# 813   '-           [NR]     MFF-DT, COL4A3
# 814   '-           [NR]     MFF-DT, COL4A3
#
#                                         Reported trait  \
# 0                                      Type 1 diabetes
# 1                                      Type 1 diabetes
# 2                                      Type 1 diabetes
# 3                                      Type 1 diabetes
# 4                                      Type 1 diabetes
# ..                                                 ...
# 810  Chronic kidney disease (reduced eGFR or end st...
# 811  Chronic kidney disease (reduced eGFR or end st...
# 812  Chronic kidney disease (end stage renal diseas...
# 813  Kidney disease (reduced eGFR and albuminuria o...
# 814  Kidney disease (end stage renal disease or alb...
#
#                               Trait(s)       Background trait(s)  \
# 0             type 1 diabetes mellitus                        '-
# 1             type 1 diabetes mellitus                        '-
# 2             type 1 diabetes mellitus                        '-
# 3             type 1 diabetes mellitus                        '-
# 4             type 1 diabetes mellitus                        '-
# ..                                 ...                       ...
# 810               diabetic nephropathy  type 1 diabetes mellitus
# 811               diabetic nephropathy  type 1 diabetes mellitus
# 812               diabetic nephropathy  type 1 diabetes mellitus
# 813               diabetic nephropathy  type 1 diabetes mellitus
# 814  albuminuria, diabetic nephropathy  type 1 diabetes mellitus
#
#     Study accession      Location
# 0        GCST000539   19:10364976
# 1        GCST000539  14:100839708
# 2        GCST001394    10:6052734
# 3        GCST001394  12:111270654
# 4      GCST90095483   14:49843683
# ..              ...           ...
# 810      GCST009286     2:3697625
# 811      GCST009286    18:1811107
# 812      GCST009287   5:122438887
# 813      GCST009289   2:227256385
# 814      GCST009292   2:227256385
#
# [815 rows x 13 columns]

# %%
df[['Chromosome','Locality']] = df.Location.str.split(":", expand=True)

# %%
Chromosome6_df = df.loc[df['Chromosome'] == '6']

# %%
Chromosome6_df
# Out:
#                             P-value P-value annotation       RAF        OR  \
# Variant and risk allele
# rs924043-<b>?</b>          8 x 10-9                NaN      0.85      1.35
# rs11755527-<b>G</b>       5 x 10-12                NaN      0.47      1.13
# rs9272346-<b>G</b>       6 x 10-129                NaN        NR        '-
# rs9388489-<b>G</b>        4 x 10-13                NaN      0.45      1.17
# rs9268645-<b>?</b>       1 x 10-100                NaN        NR        '-
# ...                             ...                ...       ...       ...
# rs9272346-<b>G</b>       5 x 10-134                NaN      0.61      5.49
# rs13217044-<b>A</b>        4 x 10-6                NaN      0.71      1.15
# rs11755527-<b>?</b>        1 x 10-7                NaN  0.443857  1.203898
# rs9273368-<b>?</b>        3 x 10-78                NaN     0.301     2.439
# rs118124843-<b>T</b>       4 x 10-8                NaN     0.011      3.79
#
#                         Beta                   CI         Mapped gene  \
# Variant and risk allele
# rs924043-<b>?</b>         '-                 [NR]                  '-
# rs11755527-<b>G</b>       '-          [1.08-1.19]               BACH2
# rs9272346-<b>G</b>        '-                   '-            HLA-DQA1
# rs9388489-<b>G</b>        '-          [1.10-1.24]               CENPW
# rs9268645-<b>?</b>        '-                   '-             HLA-DRA
# ...                      ...                  ...                 ...
# rs9272346-<b>G</b>        '-          [4.83-6.24]            HLA-DQA1
# rs13217044-<b>A</b>       '-          [1.07-1.23]              PDE10A
# rs11755527-<b>?</b>       '-  [1.125016-1.288312]               BACH2
# rs9273368-<b>?</b>        '-        [2.222-2.676]  HLA-DQB1, HLA-DQA1
# rs118124843-<b>T</b>      '-                 [NR]               VARS2
#
#                                                             Reported trait  \
# Variant and risk allele
# rs924043-<b>?</b>                                          Type 1 diabetes
# rs11755527-<b>G</b>                                        Type 1 diabetes
# rs9272346-<b>G</b>                                         Type 1 diabetes
# rs9388489-<b>G</b>                                         Type 1 diabetes
# rs9268645-<b>?</b>                                         Type 1 diabetes
# ...                                                                    ...
# rs9272346-<b>G</b>                                         Type 1 diabetes
# rs13217044-<b>A</b>      Chronic kidney disease (chronic kidney disease...
# rs11755527-<b>?</b>                             Latent autoimmune diabetes
# rs9273368-<b>?</b>          Latent autoimmune diabetes vs. type 2 diabetes
# rs118124843-<b>T</b>                   Microalbuminuria in type 1 diabetes
#
#                                                                   Trait(s)  \
# Variant and risk allele
# rs924043-<b>?</b>                                 type 1 diabetes mellitus
# rs11755527-<b>G</b>                               type 1 diabetes mellitus
# rs9272346-<b>G</b>                                type 1 diabetes mellitus
# rs9388489-<b>G</b>                                type 1 diabetes mellitus
# rs9268645-<b>?</b>                                type 1 diabetes mellitus
# ...                                                                    ...
# rs9272346-<b>G</b>                                type 1 diabetes mellitus
# rs13217044-<b>A</b>           chronic kidney disease, diabetic nephropathy
# rs11755527-<b>?</b>                   latent autoimmune diabetes in adults
# rs9273368-<b>?</b>       latent autoimmune diabetes in adults, type 2 d...
# rs118124843-<b>T</b>                                  Moderate albuminuria
#
#                               Background trait(s) Study accession  \
# Variant and risk allele
# rs924043-<b>?</b>                              '-      GCST001255
# rs11755527-<b>G</b>                            '-      GCST000258
# rs9272346-<b>G</b>                             '-      GCST000258
# rs9388489-<b>G</b>                             '-      GCST000392
# rs9268645-<b>?</b>                             '-      GCST000392
# ...                                           ...             ...
# rs9272346-<b>G</b>                             '-      GCST000043
# rs13217044-<b>A</b>      type 1 diabetes mellitus      GCST003867
# rs11755527-<b>?</b>                            '-      GCST007245
# rs9273368-<b>?</b>                             '-      GCST007246
# rs118124843-<b>T</b>     type 1 diabetes mellitus      GCST009281
#
#                             Location Chromosome   Locality
# Variant and risk allele
# rs924043-<b>?</b>        6:170063801          6  170063801
# rs11755527-<b>G</b>       6:90248512          6   90248512
# rs9272346-<b>G</b>        6:32636595          6   32636595
# rs9388489-<b>G</b>       6:126377573          6  126377573
# rs9268645-<b>?</b>        6:32440750          6   32440750
# ...                              ...        ...        ...
# rs9272346-<b>G</b>        6:32636595          6   32636595
# rs13217044-<b>A</b>        6:8226764          6    8226764
# rs11755527-<b>?</b>       6:90248512          6   90248512
# rs9273368-<b>?</b>        6:32658698          6   32658698
# rs118124843-<b>T</b>      6:30919688          6   30919688
#
# [76 rows x 14 columns]
